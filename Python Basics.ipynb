# %%
import math
math.pi
# Out:
# 3.141592653589793

# %%
math.sqrt(85)
# Out:
# 9.219544457292887

# %%
import random
random.random()
# Out:
# 0.6048823039680932

# %%
random.choice([1,23,4,5])
# Out:
# 4

# %%
S='Spam'
len(S)
# Out:
# 4

# %%
S[0]
# Out:
# 'S'

# %%
S[1]
# Out:
# 'p'

# %%
S[-1]
# Out:
# 'm'

# %%
S[-2]
# Out:
# 'a'

# %%
S[len(S)-1]
# Out:
# 'm'

# %%
S
# Out:
# 'Spam'

# %%
S[1:3]
# Out:
# 'pa'

# %%
S[1:]
# Out:
# 'pam'

# %%
S
# Out:
# 'Spam'

# %%
S[0:3]
# Out:
# 'Spa'

# %%
S[:3]
# Out:
# 'Spa'

# %%
S[:-1]
# Out:
# 'Spa'

# %%
S[:]
# Out:
# 'Spam'

# %%
S+'xyz'
# Out:
# 'Spamxyz'

# %%
S*8
# Out:
# 'SpamSpamSpamSpamSpamSpamSpamSpam'

# %%
S
# Out:
# 'Spam'

# %%
S='z'+S[1:]
S
# Out:
# 'zpam'

# %%
S.find('pa')
# Out:
# 1

# %%
S
# Out:
# 'zpam'

# %%
S.replace('pa','XYZ')
# Out:
# 'zXYZm'

# %%
S
# Out:
# 'zpam'

# %%
line="aaa,bbb,ccccc,dd"
line.split(',')
# Out:
# ['aaa', 'bbb', 'ccccc', 'dd']

# %%
S='spam'
S.upper()
# Out:
# 'SPAM'

# %%
S.isalpha()
# Out:
# True

# %%
line="aaa,bbb,ccccc,ddd\n"
line=line.rstrip()
line
# Out:
# 'aaa,bbb,ccccc,ddd'

# %%
'%s,eggs,and %s'% ('spam','SPAM!')
# Out:
# 'spam,eggs,and SPAM!'

# %%
'{0}, eggs, and {1}'.format('spam','SPAM!')
# Out:
# 'spam, eggs, and SPAM!'

# %%
dir(S)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
help(S.replace)
# Out:
# Help on built-in function replace:
#
# replace(...) method of builtins.str instance
#     S.replace(old, new[, count]) -> str
#
#     Return a copy of S with all occurrences of substring
#     old replaced by new.  If the optional argument count is
#     given, only the first count occurrences are replaced.

# %%
S='A\nB\tC'
len(S)
# Out:
# 5

# %%
ord('\n')
# Out:
# 10

# %%
S='A\oB\oC'
len(S)
# Out:
# 7

# %%
msg=""" aaaaaaaaaaaaaaaaa
bbbbbb'''bbbbbbbbbbbbb""bbbbbbbbbb'bbbb
ccccccccccccccccccccccccccc"""
msg
# Out:
# ' aaaaaaaaaaaaaaaaa\nbbbbbb\'\'\'bbbbbbbbbbbbb""bbbbbbbbbb\'bbbb\nccccccccccccccccccccccccccc'

# %%
import re
match=re.match('Hello[ \t]*(.*)world','Hello   Python world')
match.group(1)
# Out:
# 'Python '

# %%
match=re.match('/(.*)/(.*)/(.*)','/usr/home/lumberjack')
match.groups()
# Out:
# ('usr', 'home', 'lumberjack')

# %%
L=[123,'spam',1.23]
len(L)
# Out:
# 3

# %%
L[0]
# Out:
# 123

# %%
L[:-1]
# Out:
# [123, 'spam']

# %%
L+[4,5,6]
# Out:
# [123, 'spam', 1.23, 4, 5, 6]

# %%
L
# Out:
# [123, 'spam', 1.23]

# %%
L.append('NI')
L
# Out:
# [123, 'spam', 1.23, 'NI', 'NI', 'NI']

# %%
L.pop(1) #Shrinking: delete an item in the middle
# Out:
# 'spam'

# %%
L
# Out:
# [123, 'NI', 'NI']

# %%
M=['bb','aa','cc']
M.sort()
M
# Out:
# ['aa', 'bb', 'cc']

# %%
M.reverse()
M
# Out:
# ['cc', 'bb', 'aa']

# %%
L
# Out:
# [123, 'NI', 'NI']

# %%
M=[[1,2,3],
  [4,5,6],
  [7,8,9]]
M
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
M[1]
# Out:
# [4, 5, 6]

# %%
M[1][2]
# Out:
# 6

# %%
col2=[row[1] for row in M]
col2
# Out:
# [2, 5, 8]
